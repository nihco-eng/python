# %%
import pandas as pd

# %%
pro = pd.read_csv('교수.csv', index_col='교수번호')
pro2 = pro.copy()
pro2.reset_index(inplace=True)
pro2 = pro2[['교수번호', '교수이름', '교수학과']]
pro2
# Out:
#    교수번호 교수이름 교수학과
# 0   221  이병렬   전산
# 1   228  이재광   전산
# 2   311  강승일   전자
# 3   509  오문환   건축

# %%
stu = pd.read_csv('학생.csv', index_col='학생번호')
stu
# Out:
#          학생이름 학생학과  학년      생년월일  지도교수
# 학생번호
# 92414029  서연우   전산   3  73/10/06   228
# 92414033  김창덕   전산   4  73/10/26   221
# 92514009  이지행   전자   4  73/11/16   311
# 92514023  김형명   전자   4  73/08/29   311
# 92454018  이원구   건축   3  74/09/30   509
# 95454003  이재영   건축   4  76/02/06   509
# 95414058  박혜경   전산   4  76/03/12   221
# 96414404  김수정   전산   3  77/12/22   228

# %%
#학생, 교수 데이터프레임 병합
pro_stu = stu.merge(pro2, how='inner', left_on = '지도교수', right_on = '교수번호')
pro_stu.drop(columns='교수번호', inplace=True)
pro_stu.sort_values('지도교수')
pro_stu
# Out:
#   학생이름 학생학과  학년      생년월일  지도교수 교수이름 교수학과
# 0  서연우   전산   3  73/10/06   228  이재광   전산
# 1  김창덕   전산   4  73/10/26   221  이병렬   전산
# 2  이지행   전자   4  73/11/16   311  강승일   전자
# 3  김형명   전자   4  73/08/29   311  강승일   전자
# 4  이원구   건축   3  74/09/30   509  오문환   건축
# 5  이재영   건축   4  76/02/06   509  오문환   건축
# 6  박혜경   전산   4  76/03/12   221  이병렬   전산
# 7  김수정   전산   3  77/12/22   228  이재광   전산

# %%
for code in pro.index:
    df =pro_stu.groupby('지도교수').get_group(code)
    print(df)
# Out:
#   학생이름 학생학과  학년      생년월일  지도교수 교수이름 교수학과
# 1  김창덕   전산   4  73/10/26   221  이병렬   전산
# 6  박혜경   전산   4  76/03/12   221  이병렬   전산
#   학생이름 학생학과  학년      생년월일  지도교수 교수이름 교수학과
# 0  서연우   전산   3  73/10/06   228  이재광   전산
# 7  김수정   전산   3  77/12/22   228  이재광   전산
#   학생이름 학생학과  학년      생년월일  지도교수 교수이름 교수학과
# 2  이지행   전자   4  73/11/16   311  강승일   전자
# 3  김형명   전자   4  73/08/29   311  강승일   전자
#   학생이름 학생학과  학년      생년월일  지도교수 교수이름 교수학과
# 4  이원구   건축   3  74/09/30   509  오문환   건축
# 5  이재영   건축   4  76/02/06   509  오문환   건축

# %%
#교수별 지도학생 목록
for idx in pro.index :
    print('-' * 64)
    row = pro.loc[idx]
    print(f'교수번호:{idx} 교수이름:{row['교수이름']}, 교수학과:{row['교수학과']}')
    filt = stu['지도교수'] == idx
    df = stu[filt]
    for idx in df.index:
        row = df.loc[idx]
        print(f'학생번호:{idx}, 학생이름:{row['학생이름']}, 학생학과:{row['학생학과']}')
# Out:
# ----------------------------------------------------------------
# 교수번호:221 교수이름:이병렬, 교수학과:전산
# 학생번호:92414033, 학생이름:김창덕, 학생학과:전산
# 학생번호:95414058, 학생이름:박혜경, 학생학과:전산
# ----------------------------------------------------------------
# 교수번호:228 교수이름:이재광, 교수학과:전산
# 학생번호:92414029, 학생이름:서연우, 학생학과:전산
# 학생번호:96414404, 학생이름:김수정, 학생학과:전산
# ----------------------------------------------------------------
# 교수번호:311 교수이름:강승일, 교수학과:전자
# 학생번호:92514009, 학생이름:이지행, 학생학과:전자
# 학생번호:92514023, 학생이름:김형명, 학생학과:전자
# ----------------------------------------------------------------
# 교수번호:509 교수이름:오문환, 교수학과:건축
# 학생번호:92454018, 학생이름:이원구, 학생학과:건축
# 학생번호:95454003, 학생이름:이재영, 학생학과:건축

# %%
pro
# Out:
#      교수이름 교수학과       임용일 교수직급       급여
# 교수번호
# 221   이병렬   전산  75/04/03  정교수  3000000
# 228   이재광   전산  91/09/19  부교수  2500000
# 311   강승일   전자  94/06/09  부교수  2300000
# 509   오문환   건축  92/10/14  조교수  2000000

# %%
stu
# Out:
#          학생이름 학생학과  학년      생년월일  지도교수
# 학생번호
# 92414029  서연우   전산   3  73/10/06   228
# 92414033  김창덕   전산   4  73/10/26   221
# 92514009  이지행   전자   4  73/11/16   311
# 92514023  김형명   전자   4  73/08/29   311
# 92454018  이원구   건축   3  74/09/30   509
# 95454003  이재영   건축   4  76/02/06   509
# 95414058  박혜경   전산   4  76/03/12   221
# 96414404  김수정   전산   3  77/12/22   228

# %%
cou = pd.read_csv('강좌.csv')
cou
# Out:
#    강좌번호     강좌이름  강의시수  강의실  담당교수  최대인원
# 0  C301    파일처리론     3  506   221   100
# 1  C401   데이터베이스     3  414   221    80
# 2  C421     알고리즘     3  510   228    80
# 3  C312     자료구조     2  510   228   100
# 4  E221     논리회로     3  304   311   100
# 5  A109  한국의건축문화     2  101   509   120

# %%
pro2
# Out:
#    교수번호 교수이름 교수학과
# 0   221  이병렬   전산
# 1   228  이재광   전산
# 2   311  강승일   전자
# 3   509  오문환   건축

# %%
cou_pro = cou.merge(pro2, how='inner', left_on = '담당교수', right_on= '교수번호')
cou_pro
# Out:
#    강좌번호     강좌이름  강의시수  강의실  담당교수  최대인원  교수번호 교수이름 교수학과
# 0  C301    파일처리론     3  506   221   100   221  이병렬   전산
# 1  C401   데이터베이스     3  414   221    80   221  이병렬   전산
# 2  C421     알고리즘     3  510   228    80   228  이재광   전산
# 3  C312     자료구조     2  510   228   100   228  이재광   전산
# 4  E221     논리회로     3  304   311   100   311  강승일   전자
# 5  A109  한국의건축문화     2  101   509   120   509  오문환   건축

# %%
#교수별 담당강좌목록
for idx in pro.index :
    print('-' * 64)
    row = pro.loc[idx]
    print(f'교수번호:{idx} 교수이름:{row['교수이름']}, 교수학과:{row['교수학과']}')
    filt = cou['담당교수'] == idx
    df = cou[filt]
    for idx in df.index :
        row = cou.loc[idx]
        print(f'강좌명:{row['강좌이름']}, 강좌번호:{row['강좌번호']}')
print('-' * 64)
# Out:
# ----------------------------------------------------------------
# 교수번호:221 교수이름:이병렬, 교수학과:전산
# 강좌명:파일처리론, 강좌번호:C301
# 강좌명:데이터베이스, 강좌번호:C401
# ----------------------------------------------------------------
# 교수번호:228 교수이름:이재광, 교수학과:전산
# 강좌명:알고리즘, 강좌번호:C421
# 강좌명:자료구조, 강좌번호:C312
# ----------------------------------------------------------------
# 교수번호:311 교수이름:강승일, 교수학과:전자
# 강좌명:논리회로, 강좌번호:E221
# ----------------------------------------------------------------
# 교수번호:509 교수이름:오문환, 교수학과:건축
# 강좌명:한국의건축문화, 강좌번호:A109
# ----------------------------------------------------------------

# %%
enroll = pd.read_csv('수강.csv', index_col=['강좌번호', '학생번호'])
enroll
# Out:
#                     신청일    점수
# 강좌번호 학생번호
# C401 92414033  98/03/02  85.0
# C301 92414033  98/03/02  80.0
# C421 92414033  98/03/02   NaN
# C401 95414058  98/03/03  90.0
# C301 95414058  98/03/03  80.0
# C312 95414058  98/03/03  80.0
# C401 92514023  98/03/03   NaN
# C301 92514023  98/03/03  70.0
# C401 92414029  98/03/03  90.0
# C421 92414029  98/03/03   NaN
# C312 92414029  98/03/03  70.0
# E221 92414029  98/03/03  75.0
# A109 92414029  98/03/03  90.0
# C301 92514009  98/03/03  70.0
# E221 92514009  98/03/03  85.0
# C301 96414404  98/03/04  75.0
# C401 96414404  98/03/04  75.0
# C421 96414404  98/03/04  75.0
# C312 92454018  98/03/04  90.0
# E221 92454018  98/03/04  90.0
# A109 95454003  98/03/05  85.0
# C301 95454003  98/03/05  83.0
# E221 95454003  98/03/05  75.0

# %%
enroll2= pd.read_csv('수강.csv', index_col=['학생번호', '강좌번호'])
enroll2
stu = pd.read_csv('학생.csv')
stu = stu[['학생번호', '학생이름']]
stu
# Out:
#        학생번호 학생이름
# 0  92414029  서연우
# 1  92414033  김창덕
# 2  92514009  이지행
# 3  92514023  김형명
# 4  92454018  이원구
# 5  95454003  이재영
# 6  95414058  박혜경
# 7  96414404  김수정

# %%
#학생별 학생이름, 평균점수
enroll3 = pd.read_csv('수강.csv')
group = enroll3.groupby('학생번호')['점수'].mean().to_frame('평균')

stu = pd.read_csv('학생.csv', index_col='학생번호')
join = stu.join(group)
join
# Out:
#          학생이름 학생학과  학년      생년월일  지도교수         평균
# 학생번호
# 92414029  서연우   전산   3  73/10/06   228  81.250000
# 92414033  김창덕   전산   4  73/10/26   221  82.500000
# 92514009  이지행   전자   4  73/11/16   311  77.500000
# 92514023  김형명   전자   4  73/08/29   311  70.000000
# 92454018  이원구   건축   3  74/09/30   509  90.000000
# 95454003  이재영   건축   4  76/02/06   509  81.000000
# 95414058  박혜경   전산   4  76/03/12   221  83.333333
# 96414404  김수정   전산   3  77/12/22   228  75.000000

# %%
enroll3
# Out:
#     강좌번호      학생번호       신청일    점수
# 0   C401  92414033  98/03/02  85.0
# 1   C301  92414033  98/03/02  80.0
# 2   C421  92414033  98/03/02   NaN
# 3   C401  95414058  98/03/03  90.0
# 4   C301  95414058  98/03/03  80.0
# 5   C312  95414058  98/03/03  80.0
# 6   C401  92514023  98/03/03   NaN
# 7   C301  92514023  98/03/03  70.0
# 8   C401  92414029  98/03/03  90.0
# 9   C421  92414029  98/03/03   NaN
# 10  C312  92414029  98/03/03  70.0
# 11  E221  92414029  98/03/03  75.0
# 12  A109  92414029  98/03/03  90.0
# 13  C301  92514009  98/03/03  70.0
# 14  E221  92514009  98/03/03  85.0
# 15  C301  96414404  98/03/04  75.0
# 16  C401  96414404  98/03/04  75.0
# 17  C421  96414404  98/03/04  75.0
# 18  C312  92454018  98/03/04  90.0
# 19  E221  92454018  98/03/04  90.0
# 20  A109  95454003  98/03/05  85.0
# 21  C301  95454003  98/03/05  83.0
# 22  E221  95454003  98/03/05  75.0

# %%
group
# Out:
#                  평균
# 학생번호
# 92414029  81.250000
# 92414033  82.500000
# 92454018  90.000000
# 92514009  77.500000
# 92514023  70.000000
# 95414058  83.333333
# 95454003  81.000000
# 96414404  75.000000

# %%
#강좌별 강좌정보, 평균점수
group = enroll3.groupby('강좌번호')['점수'].mean().to_frame('평균')
cou = pd.read_csv('강좌.csv', index_col='강좌번호')
join = cou.join(group)
join
pro = pd.read_csv('교수.csv')
pro_s = pro[['교수번호', '교수이름']]
pro_s
# Out:
#    교수번호 교수이름
# 0   221  이병렬
# 1   228  이재광
# 2   311  강승일
# 3   509  오문환

# %%
abc = join.merge(pro_s, how='inner', left_on = '담당교수', right_on= '교수번호')
abc
# Out:
#       강좌이름  강의시수  강의실  담당교수  최대인원         평균  교수번호 교수이름
# 0    파일처리론     3  506   221   100  76.333333   221  이병렬
# 1   데이터베이스     3  414   221    80  85.000000   221  이병렬
# 2     알고리즘     3  510   228    80  75.000000   228  이재광
# 3     자료구조     2  510   228   100  80.000000   228  이재광
# 4     논리회로     3  304   311   100  81.250000   311  강승일
# 5  한국의건축문화     2  101   509   120  87.500000   509  오문환

# %%
enroll3.groupby('강좌번호')['점수'].mean().to_frame('평균')
# Out:
#              평균
# 강좌번호
# A109  87.500000
# C301  76.333333
# C312  80.000000
# C401  85.000000
# C421  75.000000
# E221  81.250000

# %%
stu = pd.read_csv('학생.csv', index_col='학생번호')
enroll = pd.read_csv('수강.csv', index_col=['학생번호', '강좌번호'])
cou = pd.read_csv('강좌.csv', index_col='강좌번호')
cou
# Out:
#          강좌이름  강의시수  강의실  담당교수  최대인원
# 강좌번호
# C301    파일처리론     3  506   221   100
# C401   데이터베이스     3  414   221    80
# C421     알고리즘     3  510   228    80
# C312     자료구조     2  510   228   100
# E221     논리회로     3  304   311   100
# A109  한국의건축문화     2  101   509   120

# %%
#학생번호를 받아서 학생이름, 수강신청한 강좌목록(강좌번호 강좌이름) 출력
scode  = 92414033
row = stu.loc[scode]
print(f'학생이름:{row['학생이름']}({scode})')

rows = enroll.loc[scode]

for idx in rows.index:
    row = rows.loc[idx]
    cou_info = cou.loc[idx]
    print(f'{cou_info['강좌이름']} {idx}, 신청일 :{row['신청일']}, 점수:{row['점수']}')
# Out:
# 학생이름:김창덕(92414033)
# 데이터베이스 C401, 신청일 :98/03/02, 점수:85.0
# 파일처리론 C301, 신청일 :98/03/02, 점수:80.0
# 알고리즘 C421, 신청일 :98/03/02, 점수:nan

# %%
#강좌번호를 입력하면 강좌이름과 이 강좌를 수강신청한 학생 목록
cou = pd.read_csv('강좌.csv', index_col='강좌번호')
cou
# Out:
#          강좌이름  강의시수  강의실  담당교수  최대인원
# 강좌번호
# C301    파일처리론     3  506   221   100
# C401   데이터베이스     3  414   221    80
# C421     알고리즘     3  510   228    80
# C312     자료구조     2  510   228   100
# E221     논리회로     3  304   311   100
# A109  한국의건축문화     2  101   509   120

# %%
pro = pd.read_csv('교수.csv', index_col='교수번호')
pro
# Out:
#      교수이름 교수학과       임용일 교수직급       급여
# 교수번호
# 221   이병렬   전산  75/04/03  정교수  3000000
# 228   이재광   전산  91/09/19  부교수  2500000
# 311   강승일   전자  94/06/09  부교수  2300000
# 509   오문환   건축  92/10/14  조교수  2000000

# %%
enroll = pd.read_csv('수강.csv', index_col=['강좌번호', '학생번호'])
enroll.loc['C301']
# Out:
#                신청일    점수
# 학생번호
# 92414033  98/03/02  80.0
# 95414058  98/03/03  80.0
# 92514023  98/03/03  70.0
# 92514009  98/03/03  70.0
# 96414404  98/03/04  75.0
# 95454003  98/03/05  83.0

# %%
stu = pd.read_csv('학생.csv', index_col= '학생번호')
stu
# Out:
#          학생이름 학생학과  학년      생년월일  지도교수
# 학생번호
# 92414029  서연우   전산   3  73/10/06   228
# 92414033  김창덕   전산   4  73/10/26   221
# 92514009  이지행   전자   4  73/11/16   311
# 92514023  김형명   전자   4  73/08/29   311
# 92454018  이원구   건축   3  74/09/30   509
# 95454003  이재영   건축   4  76/02/06   509
# 95414058  박혜경   전산   4  76/03/12   221
# 96414404  김수정   전산   3  77/12/22   228

# %%
code = 'C301'
cou_row = cou.loc[code]
cou_row
pro_row = pro.loc[cou_row['담당교수']]
print(cou_row['강좌이름'], cou_row['담당교수'], pro_row['교수이름'])
enroll_rows = enroll.loc[code]
cou_rows = cou.loc[enroll]
sum = 0
for idx, row in enroll_rows.iterrows():
    stu_row = stu.loc[idx]
    print(idx, stu_row['학생이름'], row['신청일'], row['점수'])
    sum += row['점수']
avg = sum/len(enroll_rows)
print(f'평균:{avg}')
# Out:
# 파일처리론 221 이병렬
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[215], line 7
#       5 print(cou_row['강좌이름'], cou_row['담당교수'], pro_row['교수이름'])
#       6 enroll_rows = enroll.loc[code]
# ----> 7 cou_rows = cou.loc[enroll]
#       8 sum = 0
#       9 for idx, row in enroll_rows.iterrows():
#
# File c:\Users\AIPM2\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File c:\Users\AIPM2\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexing.py:1418, in _LocIndexer._getitem_axis(self, key, axis)
#    1416 if not (isinstance(key, tuple) and isinstance(labels, MultiIndex)):
#    1417     if hasattr(key, "ndim") and key.ndim > 1:
# -> 1418         raise ValueError("Cannot index with multidimensional key")
#    1420     return self._getitem_iterable(key, axis=axis)
#    1422 # nested tuple slicing
#
# ValueError: Cannot index with multidimensional key

# %%
#학번을 입력하면 이 학생의 정보(이름, 지도교수이름, 학과)를 출력하고
#이 학생이 수강신청한 강좌번호, 강좌명, 신청일, 점수 목록 출력
#이 학생 평균점수

# %%
enroll = pd.read_csv('수강.csv', index_col=['학생번호', '강좌번호'])
enroll.loc[92414033]
# Out:
#            신청일    점수
# 강좌번호
# C401  98/03/02  85.0
# C301  98/03/02  80.0
# C421  98/03/02   NaN

# %%
code = 92414033
stu_row = stu.loc[code]
stu_row
# Out:
# 학생이름         김창덕
# 학생학과          전산
# 학년             4
# 생년월일    73/10/26
# 지도교수         221
# Name: 92414033, dtype: object

# %%
code = 92414033
enroll.fillna(0, inplace=True)
stu_row = stu.loc[code]
pro_row = pro.loc[stu_row['지도교수']]
print(stu_row['학생이름'], pro_row['교수이름'], stu_row['학생학과'])
enroll_rows = enroll.loc[code]
sum = 0
for idx, row in enroll_rows.iterrows():
    cou_row = cou.loc[idx]
    print(idx, cou_row['강좌이름'], row['신청일'], row['점수'])
    sum += row['점수']
avg = sum/len(enroll_rows)
print(f'평균:{avg}')
# Out:
# 김창덕 이병렬 전산
# C401 데이터베이스 98/03/02 85.0
# C301 파일처리론 98/03/02 80.0
# C421 알고리즘 98/03/02 0.0
# 평균:55.0

# %%
def pro_search(code):
    pro = pd.read_csv('교수.csv', index_col='교수번호')
    stu = pd.read_csv('학생.csv', index_col='학생번호')
    cou = pd.read_csv('강좌.csv', index_col='강좌번호')

    if code in pro.index:
        pro_row = pro.loc[code]
        print(code, pro_row['교수이름'], pro_row['교수학과'])
        print('담당학생-------------------------------')
        filt = stu['지도교수'] == code
        stu_rows = stu[filt]
        for idx, row in stu_rows.iterrows():
            print(idx, row['학생이름'], row['학생학과'])
        print('담당강좌--------------------------------')
        filt = cou['담당교수'] == code
        cou_rows = cou[filt]
        for idx, row in cou_rows.iterrows():
            print(idx, row['강좌이름'], row['강의시수'])

    else : 
        print('해당 교수가 없습니다.')
    

pro_search(221)
# Out:
# 221 이병렬 전산
# 담당학생-------------------------------
# 92414033 김창덕 전산
# 95414058 박혜경 전산
# 담당강좌--------------------------------
# C301 파일처리론 3
# C401 데이터베이스 3

# %%
def stu_list():
    stu = pd.read_csv('학생.csv')
    pro = pd.read_csv('교수.csv')
    merge = stu.merge(pro, left_on='지도교수', right_on='교수번호')
    merge = merge.sort_values('학생이름')
    for idx, row in merge.iterrows():
        print(row['학생번호'], row['학생이름'], row['학생학과'], row['교수이름'], end= ' ')
        print(row['생년월일'], row['학년'])

stu_list()
# Out:
# 96414404 김수정 전산 이재광 77/12/22 3
# 92414033 김창덕 전산 이병렬 73/10/26 4
# 92514023 김형명 전자 강승일 73/08/29 4
# 95414058 박혜경 전산 이병렬 76/03/12 4
# 92414029 서연우 전산 이재광 73/10/06 3
# 92454018 이원구 건축 오문환 74/09/30 3
# 95454003 이재영 건축 오문환 76/02/06 4
# 92514009 이지행 전자 강승일 73/11/16 4

# %%
def stu_search(code):
    stu = pd.read_csv('학생.csv', index_col='학생번호')
    pro = pd.read_csv('교수.csv', index_col='교수번호')
    enroll = pd.read_csv('수강.csv', index_col=['학생번호', '강좌번호'])
    enroll.fillna(0, inplace=True)
    cou = pd.read_csv('강좌.csv', index_col='강좌번호')
    
    stu_row = stu.loc[code]
    advisor = stu_row['지도교수']
    pro_row = pro.loc[advisor]
    print(stu_row['학생이름'], stu_row['학생학과'], pro_row['교수이름'])
    
    print('\n수강과목')
    print('-' * 50)
    enroll_rows = enroll.loc[code]
    
    sum = 0
    for idx, row in enroll_rows.iterrows():
        cou_row = cou.loc[idx]
        print(idx, cou_row['강좌이름'], row['신청일'], row['점수']) 
        sum += row['점수']
    avg = sum/len(enroll_rows)
    print(f'평균:{avg:.2f}')
    



stu_search(92514009)
# Out:
# 이지행 전자 강승일
#
# 수강과목
# --------------------------------------------------
# C301 파일처리론 98/03/03 70.0
# E221 논리회로 98/03/03 85.0
# 평균:77.50

# %%
import pandas as pd

pro = pd.read_csv('교수.csv', index_col='교수번호')
pro.head(2)
# Out:
#      교수이름 교수학과       임용일 교수직급       급여
# 교수번호
# 221   이병렬   전산  75/04/03  정교수  3000000
# 228   이재광   전산  91/09/19  부교수  2500000

# %%
pro2 = pro.copy()
pro2.head(2)
# Out:
#    교수번호 교수이름
# 0   221  이병렬
# 1   228  이재광

# %%
pro.index, pro.columns
# Out:
# (Index([221, 228, 311, 509], dtype='int64', name='교수번호'),
#  Index(['교수이름', '교수학과', '임용일', '교수직급', '급여'], dtype='object'))

# %%
pro.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, 221 to 509
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   교수이름    4 non-null      object
#  1   교수학과    4 non-null      object
#  2   임용일     4 non-null      object
#  3   교수직급    4 non-null      object
#  4   급여      4 non-null      int64
# dtypes: int64(1), object(4)
# memory usage: 192.0+ bytes

# %%
pro.isnull().sum()
# Out:
# 교수이름    0
# 교수학과    0
# 임용일     0
# 교수직급    0
# 급여      0
# dtype: int64

# %%
pro.loc[221].to_frame()
# Out:
#            221
# 교수이름       이병렬
# 교수학과        전산
# 임용일   75/04/03
# 교수직급       정교수
# 급여     3000000

# %%
pro.loc[:,'교수이름']
# Out:
# 교수번호
# 221    이병렬
# 228    이재광
# 311    강승일
# 509    오문환
# Name: 교수이름, dtype: object

# %%
stu = pd.read_csv('학생.csv')
stu.set_index('학생번호', inplace=True)
stu.head(2)
# Out:
#          학생이름 학생학과  학년      생년월일  지도교수
# 학생번호
# 92414029  서연우   전산   3  73/10/06   228
# 92414033  김창덕   전산   4  73/10/26   221

# %%
pro = pd.read_csv('교수.csv')
pro = pro[['교수번호', '교수이름']]
pro.head(2)
# Out:
#    교수번호 교수이름
# 0   221  이병렬
# 1   228  이재광

# %%
merge = pd.merge(stu, pro2, left_on='지도교수', right_on= '교수번호')
merge.head()
# Out:
#   학생이름 학생학과  학년      생년월일  지도교수  교수번호 교수이름 교수학과
# 0  서연우   전산   3  73/10/06   228   228  이재광   전산
# 1  김창덕   전산   4  73/10/26   221   221  이병렬   전산
# 2  이지행   전자   4  73/11/16   311   311  강승일   전자
# 3  김형명   전자   4  73/08/29   311   311  강승일   전자
# 4  이원구   건축   3  74/09/30   509   509  오문환   건축

# %%
cou = pd.read_csv('강좌.csv', index_col='강좌번호')
pro2
# Out:
#    교수번호 교수이름 교수학과
# 0   221  이병렬   전산
# 1   228  이재광   전산
# 2   311  강승일   전자
# 3   509  오문환   건축

# %%
merge = cou.merge(pro2, left_on='담당교수', right_on='교수번호')
merge.drop(columns='교수번호', inplace=True)
merge.head(2)
# Out:
#      강좌이름  강의시수  강의실  담당교수  최대인원 교수이름 교수학과
# 0   파일처리론     3  506   221   100  이병렬   전산
# 1  데이터베이스     3  414   221    80  이병렬   전산

# %%
enroll = pd.read_csv('수강.csv', index_col=['강좌번호', '학생번호'])
enroll2 = enroll.reset_index(['강좌번호', '학생번호'])
enroll2.head()
# Out:
#    강좌번호      학생번호       신청일    점수
# 0  C401  92414033  98/03/02  85.0
# 1  C301  92414033  98/03/02  80.0
# 2  C421  92414033  98/03/02   NaN
# 3  C401  95414058  98/03/03  90.0
# 4  C301  95414058  98/03/03  80.0

# %%
stu2 = stu.copy()
stu2.reset_index(inplace=True)
stu2 = stu2[['학생번호', '학생이름']]
stu2.head(2)
# Out:
#        학생번호 학생이름
# 0  92414029  서연우
# 1  92414033  김창덕

# %%
merge = enroll2.merge(stu2, on= '학생번호')
group = merge.groupby(['학생번호', '학생이름'])['점수'].mean()
group = group.to_frame()
group.head(2)
# Out:
#                   점수
# 학생번호     학생이름
# 92414029 서연우   81.25
# 92414033 김창덕   82.50

# %%
group2 = group.copy()
group.reset_index(inplace=True)
group2.sort_values('학생이름', inplace=True)
group2
# Out:
#                       점수
# 학생번호     학생이름
# 96414404 김수정   75.000000
# 92414033 김창덕   82.500000
# 92514023 김형명   70.000000
# 95414058 박혜경   83.333333
# 92414029 서연우   81.250000
# 92454018 이원구   90.000000
# 95454003 이재영   81.000000
# 92514009 이지행   77.500000

# %%
cou = pd.read_csv('강좌.csv', index_col='강좌번호')
cou
# Out:
#          강좌이름  강의시수  강의실  담당교수  최대인원
# 강좌번호
# C301    파일처리론     3  506   221   100
# C401   데이터베이스     3  414   221    80
# C421     알고리즘     3  510   228    80
# C312     자료구조     2  510   228   100
# E221     논리회로     3  304   311   100
# A109  한국의건축문화     2  101   509   120

# %%
enroll = pd.read_csv('수강.csv', index_col=['강좌번호', '학생번호'])
enroll
# Out:
#                     신청일    점수
# 강좌번호 학생번호
# C401 92414033  98/03/02  85.0
# C301 92414033  98/03/02  80.0
# C421 92414033  98/03/02   NaN
# C401 95414058  98/03/03  90.0
# C301 95414058  98/03/03  80.0
# C312 95414058  98/03/03  80.0
# C401 92514023  98/03/03   NaN
# C301 92514023  98/03/03  70.0
# C401 92414029  98/03/03  90.0
# C421 92414029  98/03/03   NaN
# C312 92414029  98/03/03  70.0
# E221 92414029  98/03/03  75.0
# A109 92414029  98/03/03  90.0
# C301 92514009  98/03/03  70.0
# E221 92514009  98/03/03  85.0
# C301 96414404  98/03/04  75.0
# C401 96414404  98/03/04  75.0
# C421 96414404  98/03/04  75.0
# C312 92454018  98/03/04  90.0
# E221 92454018  98/03/04  90.0
# A109 95454003  98/03/05  85.0
# C301 95454003  98/03/05  83.0
# E221 95454003  98/03/05  75.0

# %%
pro = pd.read_csv('교수.csv', index_col='교수번호')
pro.reset_index('교수번호')
# Out:
#    교수번호 교수이름 교수학과       임용일 교수직급       급여
# 0   221  이병렬   전산  75/04/03  정교수  3000000
# 1   228  이재광   전산  91/09/19  부교수  2500000
# 2   311  강승일   전자  94/06/09  부교수  2300000
# 3   509  오문환   건축  92/10/14  조교수  2000000

# %%
join = enroll.join(cou)
abc = join.reset_index(['강좌번호', '학생번호'])
k =abc.drop(columns =['학생번호', '신청일', '강의실', '최대인원'])
k = k.set_index('강좌번호')
j = k.groupby('강좌번호')['점수'].mean().to_frame('강좌평균점수')
kj = k.join(j)
kj = kj.drop(columns= '점수')
kj = kj.reset_index('강좌번호')
kj = pd.merge(kj, pro, left_on = '담당교수', right_on='교수번호')
kj = kj.drop(columns=['교수학과', '임용일', '교수직급', '급여'])
kj = kj.groupby(['강좌번호', '강좌이름', '강의시수', '담당교수', '교수이름'])['강좌평균점수'].mean().to_frame()
kj = kj.reset_index(['강좌번호', '강좌이름', '강의시수', '담당교수', '교수이름'])
kj
# Out:
#    강좌번호     강좌이름  강의시수  담당교수 교수이름     강좌평균점수
# 0  A109  한국의건축문화     2   509  오문환  87.500000
# 1  C301    파일처리론     3   221  이병렬  76.333333
# 2  C312     자료구조     2   228  이재광  80.000000
# 3  C401   데이터베이스     3   221  이병렬  85.000000
# 4  C421     알고리즘     3   228  이재광  75.000000
# 5  E221     논리회로     3   311  강승일  81.250000

# %%
result = kj.copy()
result = result.iloc[:, [0, 2, 4, 3, 1, 5]]
result.set_index('강좌번호', inplace=True)
result
# Out:
#       강의시수 교수이름  담당교수     강좌이름     강좌평균점수
# 강좌번호
# A109     2  오문환   509  한국의건축문화  87.500000
# C301     3  이병렬   221    파일처리론  76.333333
# C312     2  이재광   228     자료구조  80.000000
# C401     3  이병렬   221   데이터베이스  85.000000
# C421     3  이재광   228     알고리즘  75.000000
# E221     3  강승일   311     논리회로  81.250000

# %%
cou = pd.read_csv('강좌.csv')
cou.tail()
# Out:
#    강좌번호     강좌이름  강의시수  강의실  담당교수  최대인원
# 2  C421     알고리즘     3  510   228    80
# 3  C312     자료구조     2  510   228   100
# 4  E221     논리회로     3  304   311   100
# 5  A109  한국의건축문화     2  101   509   120
# 6  A108    건축학개론     2  101   509   120

# %%
enroll = pd.read_csv('수강.csv')
group = enroll.groupby('강좌번호').size().to_frame('수강인원')
group.reset_index(inplace=True)
group
# Out:
#    강좌번호  수강인원
# 0  A109     2
# 1  C301     6
# 2  C312     3
# 3  C401     5
# 4  C421     3
# 5  E221     4

# %%
merge = pd.merge(cou, group, how='left', on='강좌번호')
merge.fillna({'수강인원':0}, inplace=True)
merge['수강인원'] = merge['수강인원'].astype(int)
merge
# Out:
#    강좌번호     강좌이름  강의시수  강의실  담당교수  최대인원  수강인원
# 0  C301    파일처리론     3  506   221   100     6
# 1  C401   데이터베이스     3  414   221    80     5
# 2  C421     알고리즘     3  510   228    80     3
# 3  C312     자료구조     2  510   228   100     3
# 4  E221     논리회로     3  304   311   100     4
# 5  A109  한국의건축문화     2  101   509   120     2
# 6  A108    건축학개론     2  101   509   120     0

# %%
stu = pd.read_csv('학생.csv')
stu
# Out:
#        학생번호 학생이름 학생학과  학년      생년월일  지도교수
# 0  92414029  서연우   전산   3  73/10/06   228
# 1  92414033  김창덕   전산   4  73/10/26   221
# 2  92514009  이지행   전자   4  73/11/16   311
# 3  92514023  김형명   전자   4  73/08/29   311
# 4  92454018  이원구   건축   3  74/09/30   509
# 5  95454003  이재영   건축   4  76/02/06   509
# 6  95414058  박혜경   전산   4  76/03/12   221
# 7  96414404  김수정   전산   3  77/12/22   228

# %%
cou = pd.read_csv('강좌.csv')
cou.tail()
b= cou[['강좌번호', '담당교수']]
b
# Out:
#    강좌번호  담당교수
# 0  C301   221
# 1  C401   221
# 2  C421   228
# 3  C312   228
# 4  E221   311
# 5  A109   509
# 6  A108   509

# %%
enroll = pd.read_csv('수강.csv')
group = enroll.groupby('학생번호').size().to_frame('강좌수')
stu = pd.read_csv('학생.csv')
merge = stu.merge(group, how='left', on='학생번호')
merge.fillna({'강좌수':0}, inplace=True)
merge.set_index('학생번호', inplace=True)
merge['강좌수'] = merge['강좌수'].astype(int)
merge
# Out:
#          학생이름 학생학과  학년      생년월일  지도교수  강좌수
# 학생번호
# 92414029  서연우   전산   3  73/10/06   228    5
# 92414033  김창덕   전산   4  73/10/26   221    3
# 92514009  이지행   전자   4  73/11/16   311    2
# 92514023  김형명   전자   4  73/08/29   311    2
# 92454018  이원구   건축   3  74/09/30   509    2
# 95454003  이재영   건축   4  76/02/06   509    3
# 95414058  박혜경   전산   4  76/03/12   221    3
# 96414404  김수정   전산   3  77/12/22   228    3

# %%
group
# Out:
#           강좌수
# 학생번호
# 92414029    5
# 92414033    3
# 92454018    2
# 92514009    2
# 92514023    2
# 95414058    3
# 95454003    3
# 96414404    3

# %%
group1 = enroll.groupby(['학생번호','신청일']).size().to_frame('강좌수')
group1
# Out:
#                    강좌수
# 학생번호     신청일
# 92414029 98/03/03    5
# 92414033 98/03/02    3
# 92454018 98/03/04    2
# 92514009 98/03/03    2
# 92514023 98/03/03    2
# 95414058 98/03/03    3
# 95454003 98/03/05    3
# 96414404 98/03/04    3
