# %%
import matplotlib.pyplot as plt
plt.rc('font', family='Malgun Gothic')
plt.rc('axes', unicode_minus=False)

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
df = pd.read_excel('201508.xlsx', skiprows=3, index_col='행정기관')
df
# Out:
#                행정기관코드       남 인구수     연령구간인구수       0~4세       5~9세  \
# 행정기관
# 전국                  0  25,730,212  25,730,212  1,173,085  1,192,339
# 서울특별시      1100000000   4,953,797   4,953,797    205,096    199,153
# 부산광역시      2600000000   1,738,010   1,738,010     69,689     67,234
# 대구광역시      2700000000   1,238,966   1,238,966     52,479     54,987
# 인천광역시      2800000000   1,466,588   1,466,588     69,887     69,440
# 광주광역시      2900000000     731,412     731,412     35,564     38,848
# 대전광역시      3000000000     762,347     762,347     37,128     38,097
# 울산광역시      3100000000     603,331     603,331     30,527     29,497
# 세종특별자치시    3600000000      97,435      97,435      6,800      6,890
# 경기도        4100000000   6,271,034   6,271,034    313,725    326,479
# 강원도        4200000000     780,655     780,655     30,290     33,398
# 충청북도       4300000000     797,758     797,758     35,931     37,139
# 충청남도       4400000000   1,051,093   1,051,093     50,366     51,244
# 전라북도       4500000000     929,786     929,786     39,808     42,738
# 전라남도       4600000000     951,080     951,080     39,956     40,879
# 경상북도       4700000000   1,355,736   1,355,736     58,795     57,007
# 경상남도       4800000000   1,690,969   1,690,969     81,532     82,456
# 제주특별자치도    5000000000     310,215     310,215     15,512     16,853
#
#               10~14세     15~19세     20~24세     25~29세     30~34세  ...  \
# 행정기관                                                              ...
# 전국         1,314,587  1,718,611  1,867,477  1,644,793  1,941,125  ...
# 서울특별시        222,610    298,092    355,729    371,394    438,887  ...
# 부산광역시         76,995    108,775    130,027    110,577    126,376  ...
# 대구광역시         66,286     90,654     99,166     79,886     84,273  ...
# 인천광역시         73,815     96,838    110,914     97,539    115,640  ...
# 광주광역시         45,097     59,305     58,478     44,809     54,537  ...
# 대전광역시         42,783     55,653     59,768     52,067     57,651  ...
# 울산광역시         31,758     44,079     47,910     40,284     46,933  ...
# 세종특별자치시        5,959      5,170      5,494      5,333      8,000  ...
# 경기도          347,104    432,135    451,324    397,548    481,743  ...
# 강원도           39,139     51,845     59,666     44,589     47,606  ...
# 충청북도          41,224     54,364     58,024     48,521     55,497  ...
# 충청남도          53,737     67,064     67,960     62,210     78,501  ...
# 전라북도          49,657     65,260     65,481     50,459     57,942  ...
# 전라남도          47,178     64,148     63,018     47,006     56,756  ...
# 경상북도          63,329     85,764     93,019     79,647     89,799  ...
# 경상남도          89,209    117,239    119,703     96,563    120,322  ...
# 제주특별자치도       18,707     22,226     21,796     16,361     20,662  ...
#
#             55~59세.1   60~64세.1   65~69세.1   70~74세.1 75~79세.1 80~84세.1  \
# 행정기관
# 전국         1,978,251  1,429,060  1,114,108  1,006,343  817,164  536,925
# 서울특별시        404,467    299,727    234,916    185,847  130,520   80,112
# 부산광역시        163,160    124,762     94,143     77,796   57,177   34,927
# 대구광역시         99,711     74,720     55,409     49,043   38,138   23,963
# 인천광역시        111,773     71,554     53,823     45,078   35,890   23,928
# 광주광역시         51,562     35,841     29,608     24,744   19,008   12,455
# 대전광역시         56,477     38,588     28,200     24,420   18,921   12,636
# 울산광역시         44,412     28,968     18,370     14,817   11,239    7,321
# 세종특별자치시        5,529      4,095      3,222      3,140    2,748    2,020
# 경기도          431,791    287,769    220,451    194,362  153,990   99,174
# 강원도           67,011     48,548     37,343     40,855   34,164   21,428
# 충청북도          61,451     44,968     33,105     35,592   31,275   21,466
# 충청남도          74,712     57,236     47,724     48,686   45,750   32,428
# 전라북도          71,530     55,658     50,296     48,703   43,800   31,085
# 전라남도          73,018     57,820     54,426     59,329   56,357   37,410
# 경상북도         110,772     88,639     67,871     72,370   65,869   45,163
# 경상남도         129,145     94,520     71,974     69,612   61,852   43,364
# 제주특별자치도       21,730     15,647     13,227     11,949   10,466    8,045
#
#           85~89세.1 90~94세.1 95~99세.1 100세 이상.1
# 행정기관
# 전국         276,033  100,463   23,918    12,108
# 서울특별시       43,626   16,947    4,679     3,669
# 부산광역시       17,856    5,887    1,323     1,140
# 대구광역시       11,132    3,744      854       413
# 인천광역시       12,876    4,752    1,105       491
# 광주광역시        6,628    2,446      615       279
# 대전광역시        6,494    2,369      522       209
# 울산광역시        3,893    1,412      271       110
# 세종특별자치시      1,077      396       79        22
# 경기도         52,085   19,224    4,549     2,159
# 강원도         11,970    4,284    1,042       387
# 충청북도        10,380    3,695      844       314
# 충청남도        15,625    5,665    1,360       519
# 전라북도        15,608    5,399    1,398       500
# 전라남도        19,279    7,087    1,623       656
# 경상북도        22,167    7,887    1,816       570
# 경상남도        21,294    7,144    1,283       481
# 제주특별자치도      4,043    2,125      555       189
#
# [18 rows x 47 columns]

# %%
import pandas as pd
df_m = pd.read_excel('201508.xlsx', skiprows=3, index_col='행정기관', usecols='B, E:Y')
df_m = df_m.head(1)
df_m.iloc[0] = df_m.iloc[0].str.replace(',', '').astype(int)
df_m.iloc[0,0]
df_m
# Out:
#          0~4세     5~9세   10~14세   15~19세   20~24세   25~29세   30~34세   35~39세  \
# 행정기관
# 전국    1173085  1192339  1314587  1718611  1867477  1644793  1941125  1994086
#
#        40~44세   45~49세  ...   55~59세   60~64세   65~69세  70~74세  75~79세  \
# 행정기관                    ...
# 전국    2269072  2259198  ...  1979228  1372295  1025276  814679  557342
#
#       80~84세  85~89세 90~94세 95~99세 100세 이상
# 행정기관
# 전국    275691  100390  31277   6776    3719
#
# [1 rows x 21 columns]

# %%
df_w = pd.read_excel('201508.xlsx', skiprows=3, index_col='행정기관', usecols='B, AB:AV')
df_w = df_w.head(1)
df_w.iloc[0]= df_w.iloc[0].str.replace(',', '').astype(int)
df_w
# Out:
#        0~4세.1   5~9세.1 10~14세.1 15~19세.1 20~24세.1 25~29세.1 30~34세.1 35~39세.1  \
# 행정기관
# 전국    1112595  1120826  1212596  1567890  1654096  1508164  1846288  1923126
#
#      40~44세.1 45~49세.1  ... 55~59세.1 60~64세.1 65~69세.1 70~74세.1 75~79세.1  \
# 행정기관                    ...
# 전국    2184993  2188595  ...  1978251  1429060  1114108  1006343   817164
#
#      80~84세.1 85~89세.1 90~94세.1 95~99세.1 100세 이상.1
# 행정기관
# 전국     536925   276033   100463    23918     12108
#
# [1 rows x 21 columns]

# %%
df_m.columns
# Out:
# Index(['0~4세', '5~9세', '10~14세', '15~19세', '20~24세', '25~29세', '30~34세',
#        '35~39세', '40~44세', '45~49세', '50~54세', '55~59세', '60~64세', '65~69세',
#        '70~74세', '75~79세', '80~84세', '85~89세', '90~94세', '95~99세', '100세 이상'],
#       dtype='object')

# %%
df_w.columns
# Out:
# Index(['0~4세.1', '5~9세.1', '10~14세.1', '15~19세.1', '20~24세.1', '25~29세.1',
#        '30~34세.1', '35~39세.1', '40~44세.1', '45~49세.1', '50~54세.1', '55~59세.1',
#        '60~64세.1', '65~69세.1', '70~74세.1', '75~79세.1', '80~84세.1', '85~89세.1',
#        '90~94세.1', '95~99세.1', '100세 이상.1'],
#       dtype='object')

# %%
df_w.columns = df_m.columns
df_w.columns
# Out:
# Index(['0~4세', '5~9세', '10~14세', '15~19세', '20~24세', '25~29세', '30~34세',
#        '35~39세', '40~44세', '45~49세', '50~54세', '55~59세', '60~64세', '65~69세',
#        '70~74세', '75~79세', '80~84세', '85~89세', '90~94세', '95~99세', '100세 이상'],
#       dtype='object')

# %%
plt.figure(figsize=(10,7))
plt.barh(df_m.columns, -df_m.iloc[0]//1000)
plt.barh(df_w.columns, df_w.iloc[0]//1000)
plt.title('2015년 대한민국 성별 인구 피라미드')
plt.savefig('2015년.png')
plt.show()

# %%
import pandas as pd
df_m = pd.read_excel('202508.xlsx', skiprows=3, index_col='행정기관', usecols='B, E:Y')
df_m = df_m.head(1)
df_m.iloc[0] = df_m.iloc[0].str.replace(',', '').astype(int)
df_m.iloc[0,0]
df_m
# Out:
#         0~4세    5~9세   10~14세   15~19세   20~24세   25~29세   30~34세   35~39세  \
# 행정기관
# 전국    641290  901277  1189034  1188702  1302165  1701021  1848983  1629349
#
#        40~44세   45~49세  ...   55~59세   60~64세   65~69세   70~74세  75~79세  \
# 행정기관                    ...
# 전국    1916816  1959452  ...  2169475  2062856  1818205  1206132  828257
#
#       80~84세  85~89세 90~94세 95~99세 100세 이상
# 행정기관
# 전국    542927  260321  72712  11686    1553
#
# [1 rows x 21 columns]

# %%
df_w = pd.read_excel('202508.xlsx', skiprows=3, index_col='행정기관', usecols='B, AB:AV')
df_w = df_w.head(1)
df_w.iloc[0]= df_w.iloc[0].str.replace(',', '').astype(int)
df_w
# Out:
#       0~4세.1  5~9세.1 10~14세.1 15~19세.1 20~24세.1 25~29세.1 30~34세.1 35~39세.1  \
# 행정기관
# 전국    611205  856757  1130226  1122157  1209925  1566651  1660136  1515273
#
#      40~44세.1 45~49세.1  ... 55~59세.1 60~64세.1 65~69세.1 70~74세.1 75~79세.1  \
# 행정기관                    ...
# 전국    1837816  1902756  ...  2148596  2072345  1916129  1358680  1013445
#
#      80~84세.1 85~89세.1 90~94세.1 95~99세.1 100세 이상.1
# 행정기관
# 전국     818992   525780   216904    51888      7338
#
# [1 rows x 21 columns]

# %%
df_w.columns = df_m.columns
df_w.columns
# Out:
# Index(['0~4세', '5~9세', '10~14세', '15~19세', '20~24세', '25~29세', '30~34세',
#        '35~39세', '40~44세', '45~49세', '50~54세', '55~59세', '60~64세', '65~69세',
#        '70~74세', '75~79세', '80~84세', '85~89세', '90~94세', '95~99세', '100세 이상'],
#       dtype='object')

# %%
plt.figure(figsize=(10,7))
plt.barh(df_m.columns, -df_m.iloc[0]//1000)
plt.barh(df_w.columns, df_w.iloc[0]//1000)
plt.title('2025년 대한민국 성별 인구 피라미드')
plt.savefig('2025년.png')
plt.show()
